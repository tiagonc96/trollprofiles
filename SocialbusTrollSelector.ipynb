# %%
import pandas as pd
import os
import json
import glob
import spacy
nlp = spacy.load('pt')


trollFile=open('C:\\Users\\tiago\\Desktop\\tese\\codigo\\pythonnotebooks\\foundTrolls.txt')


jsons=[]
for filename in glob.iglob("D:\\socialbus\\users\\*" + '*', recursive=True):
    try:
        jsons.append(pd.read_json(filename,lines=True))
       # print(filename)
        #print("deu")
    except:
        pass
        
print(str(len(jsons)) + " json files found")
# Out:
# 48 json files found

# %%
i=0
flagged=[]
for json in jsons:
    i=len(json)-1
    while(i>1):
        
        
        
    
        i=i-1

# %%
cache_dir = PATH

# %%
for line in trollFile:
    print(line)
# Out:
# 2dedostesta
#
# penta_e_FCP
#
# ShadowsNGB
#
# luismp9945
#
# garotaoslb
#
# OhlavracO
#
# Diogo89253117
#
# PtTiagoAlexPt
#
# LiberalLx
#
# Salsaparrilha4
#
# NapalmGangster
#
# libpt
#
# UnfollowingP
#
# MiguelS01094378
#
# farrapeiro77
#
# Maistre19
#
# Vergonh66049459
#
# NNN30110461
#
# turiista00
#
# barreiroF3
#
# PSaserPS
#
# Arcadodiabo
#
# ACosta12536954
#
# Casei_Imunitass
#
# colliy7
#
# Lita22968520
#
# homembrancocri1
#
# throwaway388292
#
# XTyphoon2020
#
# AlvercaMajor
#
# BroncoLeste
#
# JPE_Ribeiro
#
# RMPNunes
#
# 17rafa171
#
# cm902709
#
# Litoral38040146
#
# Conservador_PT
#
# TonyJnior6
#
# manoelo90609803
#
# SRanhoso
#
# miguezJN
#
# LG_luisgameiro
#
# xavicamper
#
# SampatoVasco
#
# polhix
#
# umgajoassim
#
# Comuna100
#
# setusyl
#
# maga_bong
#
# parkamonkey99
#
# peace_stick
#
# obossdistotudo
#
# HeroZer86595006
#
# Manuali49628359
#
# Winston1820
#
# 100barras
#
# 3CKSTR
#
# zeno_1972
#
# ssoadaldeia
