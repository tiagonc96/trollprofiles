# %%
import pandas as pd

normal=pd.read_csv("regularTweets.csv",encoding="utf-16",sep="\t")

# %%
del normal['Unnamed: 0']

# %%
normal.sort_values('username')
# Out:
#             username                                               text  \
# 7109         001Lins             @Bazinhos1982 Eu caio sempre nestas :D
# 7237      01Baltasar                       @wuantt Curti dos vocals bro
# 11848     0306Pipoca  RT @PauloSousaYT: Hoje é dia de........ ficar ...
# 13229       04jonas_  RT @UltimaaBarreira: Genial.  1986-87. https:/...
# 14993  0908_JoseLuis                            @mGTS85 Parabéns Mauro.
# ...              ...                                                ...
# 2261           znuno  @oquedizmolero E dizem-se a primeira linha do ...
# 12768     zonadiluxx  RT @MEOSudoeste: 🙋‍♂‍🙋‍♀‍⚡ https://t.co/GiCZDL...
# 11351         zrucaz  RT @BinhasOnte: Os imunes que se identifiquem ...
# 8800           zthz4           @wuantt Saudades https://t.co/apz09Da8tX
# 7717       zzedygolo  RT @O_Saloio: no Shopping já deu merda! https:...
#
#       time_of_comment  sentimentPolarity  tweetLength  nrStopwords  \
# ...

# %%
normal.to_csv("regularTweets.csv",index=False,sep="\t")
