# %%
import pandas as pd
import os
import json
import glob

jsons=[]
for filename in glob.iglob("D:\\socialbus\\users\\*" + '*', recursive=True):
    try:
        jsons.append(pd.read_json(filename,lines=True))
       # print(filename)
        #print("deu")
    except:
        pass
        
print(str(len(jsons)) + " json files found")
# Out:
# 13 json files found

# %%
def main():
    i=0
    flagged=[]
    users=[]
    for json in jsons:
        i=len(json)-1
        while(i>1):
        
            if(not is_br(json['user'][i]) and get_total_number_of_tweets(json['user'][i]) and not in_flagged(json['user'][i]['screen_name'],flagged)):
                a= is_account_created_after(json['user'][i])
                b= get_following_to_follower_ratio(json['user'][i])
                c= get_numbers_in_profile(json['user'][i])
                d= avatar_contains_face(json['user'][i])
                e= has_normal_name(json['user'][i])           
                f= contains_keywords(json['text'][i],json['user'][i])
    
                score=a+b+c+d+e+f
        
                if (not_in_users(json['user'][i]['screen_name'],users)):
                    users.append(json['user'][i]['screen_name'])
                    #print(json['user'][i]['screen_name']+" -> "+str(score))
        
                if(score>=3):
                    if(not json['user'][i]['screen_name'] in flagged):
                        flagged.append(json['user'][i]['screen_name']+" -> "+str(score))
                        print(json['user'][i]['screen_name']+" -> "+str(score))
                    
            
            i=i-1

# %%
def in_flagged(user,flagged):
    found=False
    for account in flagged:
        if account==user:
            found=True
            break
    return found

# %%
from datetime import datetime
def is_account_created_after(jsonline):

   # teste=[]
    #for json in jsons:
        #i= len(json)-1
        #while(i>1):
            fullDateArray=jsonline['created_at'].split()
            shortDate= fullDateArray[2]+" "+fullDateArray[1]+" "+fullDateArray[5]
            d1= datetime.strptime(shortDate,'%d %b %Y')
            a= datetime(2018,9,15)
            if(d1 > a):
                return 1
            else: 
                return 0

# %%
def get_following_to_follower_ratio(jsonLine):
    
      
            following=int(jsonLine['friends_count'])
            followers=int(jsonLine['followers_count'])
        
            
            if(followers!=0 and following/followers>0.66):
                return 1
            else:
                return 0

# %%
def get_total_number_of_tweets(jsonLine):
    totalTweets=int(jsonLine['statuses_count'])
    if (totalTweets > 100):
        return True
    else:
        return False

# %%
def get_numbers_in_profile(jsonLine):
    username= jsonLine['screen_name']
    numberCount=0
    for letter in username:
        if(letter.isdigit()):
            numberCount+=1
            
    if(numberCount>=4):
        return 1
    else:
        return 0

# %%
def has_normal_name(jsonLine):

    names= ['Aaliyah','Aarav','Aarnav','Aaron','Aayush','Abdoulaye','Abdul','Abdullah','Abel','Abigail','Abraão','Abrão','Absalão','Abílio','Adalberto','Adam','Adama','Adelaide','Adele','Adelina','Adonai','Adrian','Adriana','Adriano','Adriel','Adriela','Adriele','Adrien','Adrián','Adélia','Afonso','Agatha','Agostinho','Agrim','Ahmad','Aicha','Aida','Aires','Aisha','Alan','Alana','Alba','Albert','Alberto','Alcino','Alda','Aleksandr','Aleksandra','Alessandro','Alessia','Alex','Alexa','Alexander','Alexandr','Alexandra','Alexandre','Alexandro','Alexandru','Alexia','Alfredo','Aliana','Alice','Alicia','Alina','Aline','Alisa','Alisha','Alissa','Aliya','Aliyha','Aliça','Allana','Alma','Alonso','Alvin','Alycia','Alyssa','Aléxia','
    found=1
    
    for name in names:
        teste=str(jsonLine['name'])
        #print(unidecode.unidecode(name.lower()) + " in "+ teste.lower())
        #print(unidecode.unidecode(name.lower()) in  teste.lower())
        if(name.lower() in  teste.lower()):
            found=0
            #print(name)
            break
    
    #if(found==1):
    #print(jsonLine['name'])
        

    return found

# %%
def is_br(jsonLine):
    if('brasil' in str(jsonLine['location']).lower() or 'brazil' in str(jsonLine['location']).lower() or 'brasileir' in str(jsonLine['description']).lower() or 'brasil' in str(jsonLine['description']).lower() or 'flameng' in str(jsonLine['description']).lower() or 'são paulo' in str(jsonLine['location']).lower() or 'bolsonar' in str(jsonLine['location']).lower()):
        return True
    else:
        return False

# %%
def contains_keywords(jsonText,jsonUser):
    found=0
   
    
    keywords=['nacionalis','patriota','comuna','comunista','esquerdista','esquerda','esquerdalh','direita','fascista','facho','troll','chega','socialismo','liberal','preto',' be ',' il ',' ps ','ventura','livre','joacine','conservador','eutanasia','puta','caralho','merda','populista','populismo','europa']
    for word in keywords:
        textoTweet= str(jsonText).lower()
        textoBio= str(jsonUser['description']).lower()
        username=jsonUser['name'].lower()
        if word in textoTweet or word in textoBio or word in username:
            found = 1
            break
    return found

# %%
import face_recognition
from PIL import Image
import requests
from io import BytesIO
from six.moves import urllib
from skimage import io


def avatar_contains_face(jsonLine):


   
    urlAux=jsonLine['profile_image_url']
    url= urlAux.replace('_normal','')

    try:
        image = io.imread(url)
        #image = face_recognition.load_image_file(image)
        face_locations = face_recognition.face_locations(image)
      
    
        if(len(face_locations>0)):
            return 0
        else:
            return 1
    except:
        return 0

# %%
def not_in_users(name,users):
    for user in users:
        if name==user:
            return False
    return True

# %%
main()
# Out:
# tostasdenutella -> 3
# Eu19223744 -> 3
# tostasdenutella -> 3
# tostasdenutella -> 3
# sophieee2003 -> 3
# Joselei66 -> 3
# CortexFrancismo -> 3
# Plaka32326791 -> 3
# Joselei66 -> 3
# Rial41408600 -> 3
# S_da_Luz -> 3
# jahr_null -> 3
# _irriiissss -> 3
# Joselei66 -> 3
# bossito -> 3
# franguimilho -> 3
# StillN0Regret -> 3
# bossito -> 3
# bossito -> 3
# NildoAllvess -> 3
# Joselei66 -> 3
# MarcosP74300094 -> 3
# bossito -> 3
# nunabarroso -> 3
# Joselei66 -> 3
# Joselei66 -> 3
# Joselei66 -> 3
# Joselei66 -> 3
# cassiorodrigves -> 3
# MestreCapelo -> 3
# LiberalLx -> 3
# jessiicaa1703 -> 3
# Vanderl57606727 -> 3
# alhodesfeito -> 3
# Politriks1 -> 3
# CamilaC65100988 -> 3
# hmoooookay -> 3
# SunshineSometi4 -> 3
# MMarquesdaSilva -> 3
# bossito -> 3
# LiberalLx -> 3
# anmaria003 -> 3
# LiberalLx -> 3
# emrcanelas -> 3
# kikeoreidaguine -> 3
# _olasoueu_ -> 3
# OStalker3 -> 3
# EllenSi12185556 -> 3
# oquedizmolero -> 3
# naoseinaofuieu -> 3
# CheBiteco -> 3
# 0piinho_1893 -> 3
# ...
