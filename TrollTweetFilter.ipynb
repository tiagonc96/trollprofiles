# %%
import pandas as pd
import os
import json
import glob
import jsonlines

jsons=[]


for filename in glob.iglob("D:\\socialbus\\users\\*" + '*', recursive=True):
    try:
        
        jsons.append(pd.read_json(filename,lines=True))
        
       # print(filename)
        #print("deu")
    except:
        pass
        
print(str(len(jsons)) + " json files found")
# Out:
# 6 json files found

# %%
i=0
flagged=[]
for json in jsons:
    i=len(json)-1
    while(i>1):
        
        for troll in trolls:
            if(json['user'][i]['screen_name']==troll):
                print(json[1][i])
            
            
        i=i-1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Program Files (x86)\Anaconda\envs\myEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-60ecd0998838> in <module>
#       7         for troll in trolls:
#       8             if(json['user'][i]['screen_name']==troll):
# ----> 9                 print(json[1][i])
#      10
#      11
#
# C:\Program Files (x86)\Anaconda\envs\myEnv\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# C:\Program Files (x86)\Anaconda\envs\myEnv\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
class Tweet:
      
        
        def __init__(self, username,text,sentimentPolarity, time_of_comment, nrStopwords, nrHashtags, nrMentions, nrUrls, nrEmoticons, nrSwears, nrFavs,
                  nrVerbs,nrNouns,nrAdjectives,tweetLength,allCapsToWordRatio):
            self.username=username
            self.text=text
            self.sentimentPolarity=sentimentPolarity
            self.time_of_comment=time_of_comment
            self.nrStopwords=nrStopwords
            self.nrHashtags=nrHashtags
            self.nrMentions=nrMentions
            self.nrUrls=nrUrls
            self.nrEmoticons=nrEmoticons
            self.nrSwears=nrSwears
            self.nrFavs=nrFavs
            self.nrVerbs=nrVerbs
            self.nrNouns=nrNouns
            self.nrAdjectives=nrAdjectives
            self.tweetLength=tweetLength
            self.allCapsToWordRatio=allCapsToWordRatio
            
            
            
        def __str__(self):
            return self.username + " " + self.text +" " +self.time_of_comment
        
        def to_dict(self):
            return {
            'username':self.username,
            'text':self.text,
            'time_of_comment': self.time_of_comment,
            'sentimentPolarity': self.sentimentPolarity,
            'tweetLength':self.tweetLength,
            'nrStopwords': self.nrStopwords,
            'nrHashtags':self.nrHashtags,
            'nrMentions':self.nrMentions,
            'nrUrls':self.nrUrls,
            'nrEmoticons':self.nrEmoticons,
            'nrSwears':self.nrSwears,
            'nrFavs':self.nrFavs,
            'nrVerbs':self.nrVerbs,
            'nrNouns':self.nrNouns,
            'nrAdjectives':self.nrAdjectives,
            'allCapsToWordRatio':self.allCapsToWordRatio
            }

# %%
teste
# Out:
# ['2dedostesta',
#  'penta_e_FCP',
#  'ShadowsNGB',
#  'luismp9945',
#  'garotaoslb',
#  'OhlavracO',
#  'Diogo89253117',
#  'PtTiagoAlexPt',
#  'LiberalLx',
#  'Salsaparrilha4',
#  'NapalmGangster',
#  'libpt',
#  'UnfollowingP',
#  'MiguelS01094378',
#  'farrapeiro77',
#  'Maistre19',
#  'Vergonh66049459',
#  'NNN30110461',
#  'turiista00',
#  'barreiroF3',
#  'PSaserPS',
#  'Arcadodiabo',
#  'ACosta12536954',
#  'Casei_Imunitass',
#  'colliy7',
#  'Lita22968520',
#  'homembrancocri1',
#  'throwaway388292',
#  'XTyphoon2020',
#  'AlvercaMajor',
#  'BroncoLeste',
#  'JPE_Ribeiro',
#  'RMPNunes',
#  '17rafa171',
#  'cm902709',
#  'Litoral38040146',
#  'Conservador_PT',
#  'TonyJnior6',
#  'manoelo90609803',
#  'SRanhoso',
#  'miguezJN',
#  'LG_luisgameiro',
#  'xavicamper',
#  'SampatoVasco',
#  'polhix',
#  'umgajoassim',
#  'Comuna100',
#  'setusyl',
#  'maga_bong',
#  'parkamonkey99',
#  'peace_stick',
#  'obossdistotudo',
#  'HeroZer86595006',
#  'Manuali49628359',
#  'Winston1820',
#  '100barras',
#  '3CKSTR',
#  'zeno_1972',
#  'ssoadaldeia',
#  'Falcom43108758',
#  'CentenoLiberal',
#  'yansolo1975',
#  'sEsmoZ_RuiDEP',
#  'ladraodoapito',
#  'tms09071987',
#  'AmorAVerdade',
#  'Doutor_Xoninhas',
#  'Kiko31693496',
#  'AntonioCunha80',
#  'Joaoluisalmeid4',
#  'ProfessorAstrom',
#  'Elchompo4',
#  'ccccqwasd',
#  'Vougalar',
#  'CarlosMelroNeto',
#  'liberat_veritas',
#  'Miguelchenko',
#  'zeno_1972',
#  'o_inopinado',
#  'ImpulsoRacional',
#  'annieloolopes',
#  'lsdope',
#  'umconservadorpt',
#  'mtymty15',
#  'ManuelL60887104']
